# %% [markdown]
# <a href="https://colab.research.google.com/github/KewBridge/CalamusTraits/blob/main/notebooks/treatment_extraction_from_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook shows how we can extract data from a PDF format publication.
#
# First we need to install a library that helps us process PDF format files

# %%
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-5.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.12.2)
# Downloading pypdf-5.0.0-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.0.0

# %% [markdown]
# Because the Calamus monograph is published closed access, we'll need to download the PDF from the publisher and then upload it into colab storage to access it from this notebook. Click on the folder icon on the left hand toolbar in colab and then on the file upload icon. Upload the PDF format article and make a variable (`pdf_filename`) that holds the filename

# %%
pdf_filename = "38576-Article Text-39176-42143-10-20200525.pdf"

# %% [markdown]
# First we'll extract all the text and save in in a text file for examination

# %%
from pypdf import PdfReader
reader = PdfReader(pdf_filename)

with open('calamus_monograph.txt', 'w') as f:
  # Loop over each page in the PDF and write it to a text file
  # using a marker to indicate page boundaries
  for page in reader.pages:
      page_number = page.page_number + 1
      page_text = page.extract_text()
      f.write('-'*30 + str(page_number) + '-'*30 + '\n')
      f.write(page_text)
      f.write('\n'+'-'*80+'\n')

# %% [markdown]
# You should see a new file appear on the left in the file browser section of the colab interface. If the cell has finished executing and you don't see it, click the refresh icon. If you double-click the text file you'll be able to view the contents.
#
# Now we'll extract the text from the PDF and store it in a pandas dataframe for easier processing.

# %%
from pypdf import PdfReader
import pandas as pd
import re

# Define a function that will help us clean boilerplate text from lines
def cleanLine(s, page_number):
  cleaned = s
  if s.startswith('HENDERSON {page_number}'.format(page_number=page_number)) and '© 2020 Magnolia Press' in s:
    cleaned = s.split('© 2020 Magnolia Press')[1]
  elif s.startswith('A REVISION OF CALAMUS'):
    try:
      cleaned = s.split('•   {page_number}'.format(page_number=page_number))[1]
    except:
      print(s, page_number)
  else:
    cleaned = s
  return cleaned

# Open the PDF file for reading
reader = PdfReader(pdf_filename)

# Extract pages and store with their page number in a dictionary
pages = dict()
for i, page in enumerate(reader.pages):
    page_number = page.page_number + 1
    page_text = page.extract_text()
    pages[page_number] = page_text

# Make a dataframe from the pages dictionary
df_pages = pd.DataFrame(data={'page_number':pages.keys(),'page_text':pages.values()})

# Make a new column which holds the individual lines in each page
# First as a list of lines
df_pages['line'] = df_pages['page_text'].apply(lambda x: x.split('\n'))
# Now "explode" the list of lines so that each line is in its own row
# in the dataframe
df_lines = df_pages.explode('line')
# page text can be dropped as no longer needed
df_lines.drop(columns=['page_text'],inplace=True)
# Clean any boilerplate footer text from the lines
df_lines['line_cleaned'] = df_lines.apply(lambda row: cleanLine(row['line'], row['page_number']), axis=1)

print(df_lines)
# Out:
#      page_number                                               line  \
# 0              1                        Phytotaxa  445 (1): 001–656
# 0              1                      https://www.mapress.com/j/pt/
# 0              1  Copyright © 2020 Magnolia PressPHYTOTAXAISSN 1...
# 0              1                    ISSN 1179-3163 (online edition)
# 0              1  Accepted by William Baker: 11 Apr. 2020; publi...
# ..           ...                                                ...
# 654          655  leaf with regularly arranged, linear pinnae sp...
# 655          656  HENDERSON 656   •   Phytotaxa  445 (1) © 2020 ...
# 655          656  Plate 139. Calamus zollingeri  subsp. zollinge...
# 655          656  brown, the other shorter, needle-like, black, ...
# 655          656  Regularly arranged, lanceolate pinnae ( Hender...
#
#                                           line_cleaned
# 0                          Phytotaxa  445 (1): 001–656
# 0                        https://www.mapress.com/j/pt/
# 0    Copyright © 2020 Magnolia PressPHYTOTAXAISSN 1...
# 0                      ISSN 1179-3163 (online edition)
# 0    Accepted by William Baker: 11 Apr. 2020; publi...
# ..                                                 ...
# 654  leaf with regularly arranged, linear pinnae sp...
# 655
# 655  Plate 139. Calamus zollingeri  subsp. zollinge...
# 655  brown, the other shorter, needle-like, black, ...
# 655  Regularly arranged, lanceolate pinnae ( Hender...
#
# [13810 rows x 3 columns]

# %% [markdown]
# Next, we'll see if we can identify the different sections of the article

# %%
# Here we map between the section identifer that we want to establish,
# and the line that represents the start of this section

section_mapper={'abstract':'Abstract',
'introduction':'Introduction',
'materials_and_methods':'Materials and Methods',
'distribution':'Distribution',
'morphology':'Morphology',
'taxonomic_treatment':'Taxonomic Treatment',
'acknowledgements':'Acknowledgements',
'references':'References',
'appendix_1':'Appendix I. Quantitative variables',
'appendix_2':'Appendix II. Qualitative Variables',
'appendix_3':'Appendix III. Excluded and Uncertain Names',
'appendix_4':'Appendix IV . Species by Region/Island/Country',
'appendix_6':'Appendix VI. Plates'}

# Add a column to df_lines so that we can categorise the line
# into its enclosing section
df_lines['section']=[None]*len(df_lines)

# Loop over the section mapper and update the df_lines dataframe with
# the appropriate section
for key, value in section_mapper.items():
  mask=(df_lines.line_cleaned.str.match(r'^{}\s*$'.format(value.replace('.','\\.')), case=False, flags=0, na=None))
  df_lines.loc[mask, 'section'] = key

# Now we have the start lines for each section, we can use the
# pandas filldown function to categrise each line
df_lines.section.ffill(inplace=True)

print(df_lines.groupby(df_lines.section).size())
# Out:
# section
# abstract                    10
# acknowledgements            13
# appendix_1                   5
# appendix_2                  85
# appendix_3                 249
# appendix_4                1511
# appendix_6                 524
# distribution                42
# introduction                45
# materials_and_methods       88
# morphology                 397
# references                 454
# taxonomic_treatment      10359
# dtype: int64

# %% [markdown]
# Now we'll look for the lines which indicate the start of a taxon treatment, and we'll establish a column identifying the taxon treatement, using the same (filldown) principle as above.

# %%
# Define regular expression patterns to find the start lines of taxon treatments
species_treatment_patt = r'^[0-9]+\s*\.\s+Calamus\s+.*$'
infraspecies_treatment_patt = r'^[0-9]+[a-z]\s*\.\s+Calamus\s+[a-z]+\s+subsp\.\s+.*$'

# Utility functions to extract number and name from the line indicating the
# start of a taxonomic treatment
def extractSpeciesNumberAndName(s):
  speciesNumberAndName = None
  if s is not None:
    patt = r'^(?P<species_id>[0-9]+)\s*\.\s+(?P<species_name>Calamus\s+[a-z]+)\s+.*$'
    m = re.match(patt, s)
    if m is not None:
      speciesNumberAndName = m.groupdict()['species_id'] + ' ' + m.groupdict()['species_name']
  return speciesNumberAndName

def extractInfraSpeciesNumberAndName(s):
  infraspeciesNumberAndName = None
  if s is not None:
    patt = r'^(?P<species_id>[0-9]+[a-z])\s*\.\s+(?P<species_name>Calamus\s+[a-z]+\s+subsp\.\s+[a-z]+).*$'
    m = re.match(patt, s)
    if m is not None:
      infraspeciesNumberAndName = m.groupdict()['species_id'] + ' ' + m.groupdict()['species_name']
  return infraspeciesNumberAndName

# Make a new column to hold the taxon_id_and_name
df_lines['taxon_id_and_name']=[None]*len(df_lines)
#  As we're using filldown, we want to set the endpoint after the taxon
# treatments. This prevents the last taxon treatment being filled down right
# to the end of the article
mask=(df_lines.line_cleaned.str.match('^Acknowledgements\s*$'))
df_lines.loc[mask, 'taxon_id_and_name'] = 'na'

# Find the lines which indicate the start of an infraspecific treatment
mask=(df_lines.line_cleaned.str.match(infraspecies_treatment_patt, case=True, flags=0, na=None))
# Use the utility function to extract the taxon name and number fromthe text
# of the line
df_lines.loc[mask, 'taxon_id_and_name'] = df_lines[mask].line_cleaned.apply(extractInfraSpeciesNumberAndName)

# As above - find the lines which indicate the start of an species treatment
mask=(df_lines.line_cleaned.str.match(species_treatment_patt, case=True, flags=0, na=None))
# Use the utility function to extract the taxon name and number from the text
# of the line
mask = (df_lines.taxon_id_and_name.isnull() & mask)
df_lines.loc[mask, 'taxon_id_and_name'] = df_lines[mask].line_cleaned.apply(extractSpeciesNumberAndName)

# Fill down the taxon name and number values
df_lines.taxon_id_and_name.ffill(inplace=True)

# Group to show how many lines were allocated to each taxonomic treatment
pd.set_option('display.max_rows',500)
print(df_lines.groupby(df_lines.taxon_id_and_name).size())
# Out:
# taxon_id_and_name
# 1 Calamus acamptostachys                                    16
# 10 Calamus andamanicus                                      28
# 100 Calamus erectus                                         35
# 101 Calamus erinaceus                                       25
# 101a Calamus erinaceus subsp.  erinaceus                     9
# 101b Calamus erinaceus subsp.  daemonoropoides              11
# 102 Calamus erioacanthus                                    48
# 103 Calamus erythrocarpus                                   14
# 104 Calamus essigii                                         12
# 105 Calamus eugenei                                         13
# 106 Calamus  evansii                                        15
# 107 Calamus exiguus                                         25
# 108 Calamus exilis                                          41
# 109 Calamus fertilis                                        14
# 11 Calamus anomalus                                         23
# 110 Calamus filipendulus                                    15
# 111 Calamus filispadix                                      16
# 112 Calamus fissilis                                        15
# 113 Calamus flabellatus                                     51
# 114 Calamus flagellum                                       22
# 115 Calamus floribundus                                     16
# 116 Calamus formicarius                                     15
# 117 Calamus formosanus                                      19
# 118 Calamus furvus                                          11
# 119 Calamus gaharuensis                                     13
# 12 Calamus applanatus                                       23
# 120 Calamus gajoensis                                       16
# 121 Calamus  gamblei                                        29
# 122 Calamus geniculatus                                     34
# 123 Calamus gibbsianus                                      25
# 124 Calamus glaucescens                                     12
# 125 Calamus godefroyi                                       20
# 126 Calamus gonospermus                                     16
# 127 Calamus goramensis                                      16
# 128 Calamus gracilipes                                      42
# 129 Calamus gracilis                                        23
# 129a Calamus gracilis subsp.  gracilis                       8
# 129b Calamus gracilis  subsp. vietnamensis                   6
# 13 Calamus arborescens                                      19
# 130 Calamus griseus                                         15
# 131 Calamus guruba                                          25
# 132 Calamus hallierianus                                    27
# 133 Calamus harmandii                                       14
# 134 Calamus heatubunii                                      13
# 135 Calamus helferianus                                     46
# 411a Calamus zonatus  subsp. zonatus                        10
# 411b Calamus zonatus subsp.  corneri                        12
# 42 Calamus brevissimus                                      12
# 43 Calamus brunneus                                         20
# 44 Calamus bulubabi                                         17
# 45 Calamus burckianus                                       17
# 46 Calamus burkillianus                                     20
# 47 Calamus caesius                                          23
# 48 Calamus calapparius                                      25
# 49 Calamus calciphilus                                      20
# 5 Calamus acaulis                                           12
# 50 Calamus calicarpus                                       27
# 51 Calamus calospathus                                      19
# 52 Calamus capillosus                                       12
# 53 Calamus caryotoides                                      14
# 54 Calamus castaneus                                        26
# 55 Calamus caurinus                                         15
# 56 Calamus centralis                                        14
# 57 Calamus ceratophorus                                     11
# 58 Calamus cheirophyllus                                    17
# 59 Calamus ciliaris                                         17
# 6 Calamus adspersus                                         21
# 60 Calamus cinereus                                         12
# 61 Calamus clivorum                                         12
# 62 Calamus cockburnii                                       14
# 63 Calamus  compsostachys                                   18
# 64 Calamus comptus                                          20
# 65 Calamus concinnus                                        16
# 66 Calamus concolor                                         29
# 67 Calamus confusus                                         24
# 68 Calamus conirostris                                      32
# 69 Calamus conjugatus                                       17
# 7 Calamus aidae                                             22
# 70 Calamus conspectus                                       15
# 71 Calamus convallium                                       13
# 72 Calamus crassifolius                                     15
# 73 Calamus crinitus                                         31
# 73a Calamus crinitus subsp.  crinitus                       11
# 73b Calamus crinitus subsp.  forbesii                        9
# 73c Calamus crinitus subsp.  sabut                          18
# 74 Calamus cristatus                                        19
# 75 Calamus croftii                                          16
# 76 Calamus cumingianus                                      23
# 77 Calamus cuthbertsonii                                    20
# 78 Calamus dasyacanthus                                     16
# 79 Calamus deerratus                                        30
# 8 Calamus albidus                                           21
# 80 Calamus delicatulus                                      15
# 81 Calamus densifloropsis                                   19
# 82 Calamus densiflorus                                      20
# 83 Calamus depauperatus                                     31
# 84 Calamus dianbaiensis                                     22
# 85 Calamus didymocarpus                                     28
# 86 Calamus diepenhorstii                                    39
# 87 Calamus digitatus                                        16
# 88 Calamus dilaceratus                                      11
# 89 Calamus dioicus                                          20
# 9 Calamus altiscandens                                      18
# 90 Calamus discolor                                         28
# 91 Calamus disjunctus                                       14
# 92 Calamus distentus                                        13
# 93 Calamus divaricatus                                      24
# 94 Calamus divergens                                        15
# 95 Calamus dongnaiensis                                     14
# 96 Calamus dracunculus                                      18
# 97 Calamus dumetosus                                        18
# 98 Calamus egregius                                         17
# 99 Calamus elegans                                          18
# na                                                        2841
# dtype: int64

# %%
species_names = ['Calamus concolor',
                'Calamus disjunctus',
                'Calamus glaucescens',
                'Calamus hallierianus',
                'Calamus pseudoconcolor',
                'Calamus subangulatus']
for species_name in species_names:
  mask = (df_lines.taxon_id_and_name.str.contains(species_name,na=False))
  print(df_lines[mask][['line_cleaned']])
# Out:
#                                           line_cleaned
# 122  66. Calamus concolor  (Blume) Baker (2015a: 15...
# 122  concolo r Pritzel (1854: 245), orth. var. Lect...
# 122                               s.n. (lectotype L!).
# 122  Stems  clustered, climbing, 3.0 m long, 0.7(0....
# 122  a knee below the petiole; leaf sheaths with nu...
# 122  lateral veins diverging, the two distal margin...
# 122  terminating in a short, obscure stub; peduncle...
# 122  and color not recorded; fruiting perianths not...
# 122   Distribution and habitat:— Central-western Su...
# 122   Taxonomic notes:— Calamus concolor  belongs t...
# 122  C. disjunctus, C. glaucescens, C. hallierianus...
# 122  Ceratolobus . They are characterized by their ...
# 122  at the apex by two short, lateral splits (see ...
# 122  species in the group by its pinnae that are no...
# 123
# 123  Fig. 43. Distribution maps of Calamus concolor...
# 123   Calamus concolor  is a problematic species kn...
# 123  specimen ( Forbes 1561 ) was included by Drans...
# 123  As a preliminary species C. concolor  was poly...
# 123  polymorphic species, as described in the Mater...
# 123  such, it does not differ from other specimens ...
# 123  inflorescences and mature fruits of Sumatran C...
# 123  for testing differences in quantitative variab...
# 123  specimens in C. concolor  would give a species...
# 123  here recognized as a separate species, C. disj...
# 123                                     from Sumatra.
# 123   This kind of problematic variation is found i...
# 124  comprise various populations that differ from ...
# 124     species boundaries are difficult to determine.
#                                           line_cleaned
# 149  91. Calamus disjunctus  Henderson sp. nov.  Ty...
# 149  Mendulo, road to Maligan, 4 September 1983, Le...
# 149  Stems  clustered, climbing, 7.7(3.0–15.0) m lo...
# 149  petiole, with a knee below the petiole; leaf s...
# 149  rhombic, the lateral veins diverging, the two ...
# 149  of divergence, erect to arching, short, withou...
# 149  orangey-brown, or red; fruiting perianths expl...
# 149   Distribution and habitat:— Eastern Borneo (Br...
# 149  49) in lowland or montane rainforest at 456(30...
# 149   Taxonomic notes:— Calamus disjunctus  (Plate ...
# 149  species for differences between C. disjunctus ...
# 149   As with other species in the Calamus concolor...
# 149  was polymorphic for three variables. However, ...
# 149  as a phylogenetic species with three variables...
#                                           line_cleaned
# 183  124. Calamus glaucescens  Dietrich (1840: 1064...
# 183  1334), non Calamus glaucescens  Blume (1847: 6...
# 183  INDONESIA. Java, no date, C. Blume s.n.  (lect...
# 183  Stems  clustered, climbing, 4.0 m long, 1.0(0....
# 183  with a knee below the petiole; leaf sheath spi...
# 183  without spinules on veins, grayish-white indum...
# 183  divergence, arching, short, without any recurv...
# 183   Distribution and habitat:— Western Java (Fig....
# 183   Taxonomic notes:— Calamus glaucescens  was pr...
# 183  concolor  group (see notes under that species)...
# 183  spines, pinnae that are indumentose abaxially,...
# 183  one, highly disturbed locality, and is no long...
#                                           line_cleaned
# 190  132. Calamus hallierianus  (Beccari ex Heyne) ...
# 190  (1913: 93). Lectotype (designated here):—INDON...
# 190                  (lectotype L!, isolectotype BO!).
# 190  Ceratolobus discolor Beccari (1886: 63) nom. i...
# 190  150). Type:—MALAYSIA. Sarawak, no date, O. Bec...
# 190  Calamus georgei  Baker (2015a: 150) . Ceratolo...
# 191  (1908a: 197). Lectotype (designated by Dransfi...
# 191  (lectotype FI!, isolectotype K!, LE n.v., LE i...
# 191  Stems  clustered, rarely solitary, climbing, 1...
# 191  closed opposite the petiole, with a knee below...
# 191  margins praemorse, without spinules on veins, ...
# 191  erect to arching, short, without any recurved ...
# 191  globose, 15.1(11.3–19.6) cm long, 13.0(9.2–16....
# 191   Distribution and habitat:— Peninsular Malaysi...
# 191  Kalimantan, Sarawak) (Fig. 60) in lowland rain...
# 191   Taxonomic notes:— Calamus hallierianus  was p...
# 191  concolor  group (see notes under that species)...
# 191  but differs from that species by its leaf shea...
# 191   Ceratolobus kingianus  is included here; it s...
# 191                                 Dransfield 1979b).
# 191   Subspecific variation:— Calamus hallierianus ...
# 191  each of the three areas where it occurs (Penin...
# 191   Specimens from Sumatra are relatively uniform...
# 191  in Borneo but mostly in the central part of th...
# 191  is said on the label to come from Sandakan in ...
# 191  specimen ( Peters s.n. ) is also unusual in it...
# 191  “seasonally inundated forest … flooded 4 to 6 ...
#                                           line_cleaned
# 362  299. Calamus pseudoconcolor  (Dransfield) Bake...
# 362  19). Type:—INDONESIA. Java, (distr. Sukabumi),...
# 362                                  isotypes K!, L!).
# 362  Stems  clustered, climbing, 2.3(1.0–4.0) m lon...
# 362  petiole, with a knee below the petiole; leaf s...
# 362  cirrus, without reduced or vestigial pinnae, a...
# 362  proximally), distantly spaced clusters of dark...
# 363  margins praemorse, without spinules on veins, ...
# 363  pinnae sometimes swept back across the sheath;...
# 363  arching, short, without any recurved spines, t...
# 363  only at the apex by two short, lateral splits;...
# 363  arranged dyads of 1 pistillate and 1 neuter fl...
# 363  longitudinally; seeds 1 per fruit, basally att...
# 363  section, the dorsal surfaces pitted, covered w...
# 363                                  600) m elevation.
# 363  Fig. 107. Distribution maps of Calamus pseudoc...
# 363                            subsp.  karnatakensis .
# 364   Taxonomic notes:— Calamus pseudoconcolor  was...
# 364  C. concolor  group (see notes under that speci...
# 364  glaucescens , but differs in its scattered spi...
# 364  pendulous inflorescences, and ellipsoid fruits...
# 364  relatively homogeneous, C. pseudoconcolor  is ...
# 364   Subspecific variation:— There seem to be thre...
# 364  specimens ( Grashoff 189, Gianno E203 ) have s...
# 364  rachises with long, straight, yellowish spines...
# 364  specimens ( Dransfield 1263, 1266 ) with simil...
# 364  of C. glaucescens ) as well as spicules. Leave...
# 364  discussed by Dransfield (1979b) who considered...
# 364  without long, straight spines, and the proxima...
#                                           line_cleaned
# 419  362. Calamus subangulatus  Miquel (1861: 594)....
# 419  subangulatus  (Miquel) Kuntze (1891: 734). Cer...
# 419  Type:—INDONESIA. Sumatra, Priaman, no date, J....
# 419  Ceratolobus laevigatus  var. angustifolius  Be...
# 419  King’ s collector 1879  (holotype K!, isotypes...
# 419  Ceratolobus laevigatus  var. major  Beccari (1...
# 419                        (holotype FI!, isotype K!).
# 419  Ceratolobus laevigatus  var. regularis  Beccar...
# 419                               FI!, isotype SING!).
# 419  Ceratolobus laevigatus  var. borneensis  Becca...
# 419                                              FI!).
# 419  Ceratolobus laevigatus  var. divaricatus  Becc...
# 419                  (holotype FI!, isotypes BO!, L!).
# 419  Stems  clustered, rarely solitary, climbing, 7...
# 420  closed opposite the petiole, with a knee below...
# 420  proximally, horizontally spreading, scattered,...
# 420  regularly arranged and spreading in the same p...
# 420  diverging from sheath well below sheath apex, ...
# 420  brown, brownish, pale brown, light brown, dark...
# 420   Distribution and habitat:— Peninsular Thailan...
# 420  East, South, and West Kalimantan, Sarawak, Sab...
# 420   Taxonomic notes:— Calamus subangulatus  was p...
# 420  concolor  group (see notes under that species)...
# 420                                            pinnae.
# 420   As a preliminary species, Calamus subangulatu...
# 420  splitting the preliminary species into several...
# 420  species with five variables treated as traits....
# 420   Subspecific variation:— Leaf sheaths of most ...
# 420  like those of some specimens of Calamus melano...
# 420  difficult to score because of the way the pinn...
# 420   Calamus subangulatus  occurs in three separat...
# 420  Borneo. Within these areas it appears to occur...
# 420   In Peninsular Malaysia it is common on the ce...
# 420  side, and just reaches Peninsular Thailand. Sp...
# 420  arranged in divergent pairs. Specimens from th...
# 420   In Sumatra it is known only from the central–...
# 420                                         prophylls.
# 420   In Borneo it is widespread but uncommon in th...
# 420  several specimens ( Ashton S.22012, Wong 322, ...
# 420  than other specimens. One specimen ( Mogea 411...
# 420                              does not seem likely.
# 421
# 421  Fig. 123. Distribution maps of Calamus  subang...

# %%
for line in df_lines.line_cleaned.tolist():
  if re.match('^[0-9]+[a-z]*\. Calamus', line):
    print(line)
# Out:
# 1. Calamus acamptostachys  (Beccari) Baker (2015a: 141).  Daemonorops acamptostachys  Beccari (1911a: 209).
# 2. Calamus acanthochlamys  Dransfield (1990: 85). Type:—MALAYSIA. Sarawak, 4
# 3. Calamus acanthophyllus  Beccari (1910: 229).  Type:—THAILAND. Expédition du Me-Kong, Rivière d’Ubon,
# 4. Calamus acanthospathus Griffith (1845: 39).  Palmijuncus acanthospathus (Griffith) Kuntze (1891: 733). Lectotype
# 5. Calamus acaulis  Henderson, Ninh Khac Ban & Nguyen Quoc Dung (2008: 188).  Type:—VIETNAM. Phu Yen
# 6. Calamus adspersus  (Blume) Blume (1847: 40). Daemonorops adspersa  Blume (1847: t. 142, 143). Palmijuncus
# 7. Calamus aidae  Fernando (1989: 49) . Type:—PHILIPPINES. Samar, Basey, Guirang, Rawis Baswood concession
# 8. Calamus albidus  Guo Lixiu & Henderson (2007: 352).  Calamus oxycarpus  var. angustifolius  Chen San-Yang
# 9. Calamus altiscandens  Burret (1939: 196).  Lectotype (designated here):—PAPUA NEW GUINEA. Palmer River,
# 10. Calamus andamanicus  Kurz (1874: 211).  Palmijuncus andamanicus  (Kurz) Kuntze (1891: 733). Lectotype
# 11. Calamus anomalus  Burret (1935: 320). Lectotype (designated here):—PAPUA NEW GUINEA. Central Division,
# 12. Calamus applanatus  (Henderson & Nguyen Quoc Dung) Henderson comb. nov.  Basionym: Daemonorops
# 13. Calamus arborescens  Griffith (1845: 33).  Palmijuncus arborescens  (Griffith) Kuntze (1891: 733). Lectotype
# 14. Calamus aruensis  Beccari (1886: 61). Palmijuncus aruensis  (Beccari) Kuntze (1891: 733). Type:—INDONESIA.
# 15. Calamus arugda  Beccari (1909a: 622). Type:—PHILIPPINES. Prov. Luzon, Cagayan, Lalloc, April 1907, W.
# 16. Calamus ashtonii  Dransfield (1980c: 9). Type:—MALAYSIA. Sarawak, S. Tubau at Tubau village, 3 April 1963,
# 407. Calamus zebrinus  Beccari (1886: 59).  Palmijuncus zebrinus  (Beccari) Kuntze (1891: 733). Type:—INDONESIA.
# 408. Calamus zeylanicus  Beccari in Hooker (1893: 455).  Lectotype (designated here):—SRI LANKA. Sassafragam,
# 409. Calamus zieckii  Fernando (2014: 74). Type:—INDONESIA. Irian Jaya, Fak–Fak, Timika, East Levee by
# 410. Calamus zollingeri  Beccari (1902b: 199).  Lectotype (designated here):—INDONESIA. Ins. Celebes, Boni,
# 410b. Calamus zollingeri  subsp. foxworthyi  (Beccari) Henderson comb. & stat. nov.  Basionym: Calamus foxworthyi
# 410c. Calamus zollingeri  subsp. merrillii  (Beccari) Henderson comb. & stat. nov.  Basionym: Calamus merrillii
# 411. Calamus zonatus  Beccari (1902a: 609).  Type:—MALAYSIA. Ragiato de Sarawak, sul Mt. Mattang, June 1866,
# 411a. Calamus zonatus  subsp. zonatus
# 411b. Calamus zonatus subsp.  corneri  (Furtado) Henderson comb. & stat. nov.  Basionym: Calamus corneri  Furtado

# %% [markdown]
# You can try modifying this so that all the descriptive information for a treatment is saved in a data structure. You'll need to:
# 1. Extract the species name (or the infraspecific name - these are indicated by an alphabetic character after the number see eg "73a. Calamus crinitus subsp.  crinitus".
# 2. Find the lines which indicate the description. These will start with the word "Stems" and proceed down to the line which starts "Distribution and habitat"
# 3. Save these lines in a data structure - maybe a dictionary keyed by species name. Initially we will only want to work with the species that were previously regarded as *Ceratolobus* ie:
#     - *Calamus concolor*
#     - *Calamus disjunctus*
#     - *Calamus glaucescens*
#     - *Calamus hallierianus*
#     - *Calamus pseudoconcolor*
#     - *Calamus subangulatus*

# %%
species_names = ['Calamus concolor',
                'Calamus disjunctus',
                'Calamus glaucescens',
                'Calamus hallierianus',
                'Calamus pseudoconcolor',
                'Calamus subangulatus']
description_lines = []
in_species_treatment = False
in_species_description = False
species_id = None
species_name = None
species_descriptions = dict()
for line in df_lines.line_cleaned.tolist():
  # Define a pattern that indicates the start of a species treatment
  # This syntax uses "named groups" to extract the species_id and species name
  patt = '^(?P<species_id>[0-9]+[a-z]*)\. (?P<species_name>Calamus [a-z]+) .*$'
  m = re.match(patt, line)
  # This tests if we found a match
  if m is not None:
    # Now we test if the species name is one that we want to extract
    # ie is it one of the list defined above ("species_names")
    if m.groupdict()['species_name'] in species_names:
      species_id = m.groupdict()['species_id']
      species_name = m.groupdict()['species_name']
      # Set a flag to indicate that we're currently inside a species treatment
      in_species_treatment = True
      continue
  if in_species_treatment:
    # When we're in a species treatement, we don't want to save lines until
    # we hit the line starting with "stems"
     if line.startswith('Stems'):
        # Set a flag to indicate that we're currently inside a species description
        in_species_description = True
  if in_species_description:
    # This test is for the end of the species description
    if line.strip().startswith('Distribution') or line.strip().startswith('Fig'):
      in_species_description = False
      # Save the data into our dictionary
      species_descriptions[species_name] = '\n'.join(description_lines)
      # clear all variables for next loop
      description_lines = []
      in_species_treatment = False
      in_species_description = False
      species_id = None
      species_name = None
    else:
      # as we're not yet at the end, just keep accumulating lines
      description_lines.append(line)

# Output our saved description data
for species_name, species_description in species_descriptions.items():
  print(species_name)
  print(species_description)
# Out:
# Calamus concolor
# Stems  clustered, climbing, 3.0 m long, 0.7(0.5–1.0) cm diameter. Leaf sheaths  tubular, closed opposite the petiole, with
# a knee below the petiole; leaf sheaths with numerous spicules borne on short, low, horizontal ridges, easily detached and leaving the sheaths with ridges only; ocreas short, membranous, not spiny, with external and internal abscission zone, splitting and falling early; flagella absent; petioles 4.3(1.0–6.0) cm long; rachises 36.2(28.5–45.0) cm long, the apices extended into an elongate cirrus, without reduced or vestigial pinnae, adaxially flat, abaxially with more or less regularly arranged (at least proximally), distantly spaced clusters of dark–tipped, recurved spines, terminating in a stub, without a shallow groove adaxially; pinnae  5(5–6) per side of rachis, regularly arranged, rhombic, the
# lateral veins diverging, the two distal margins praemorse, without spinules on veins, sometimes with few to numerous, small, brown scales abaxially; proximalmost pinnae rarely much reduced; middle pinnae 16.6(12.7–20.3) cm long, 6.4(4.6–8.0) cm wide. Inflorescences  position not recorded, erect to arching, short, without any recurved spines,
# terminating in a short, obscure stub; peduncles long, slender, pendulous, not or scarcely spiny, without a prophyll scar at the apex; prophylls flattened, persistent, usually non–spiny, splitting only at the apex by two short, lateral splits; partial inflorescences stalked; rachis bracts much reduced, papery, with one side of the oblique apex extended into a longer limb; rachillae sessile; staminate inflorescences not recorded; pistillate inflorescences branched to 2 orders, length not recorded; pistillate rachillae 0.8 cm long, with alternately and distichously arranged dyads of 1 pistillate and 1 neuter flower borne on short, stout pedicels; pistillate calyces cupular, shallowly 3-lobed; fruits  shape, size,
# and color not recorded; fruiting perianths not recorded; fruit scales deeply channeled longitudinally; seeds 1 per fruit, basally attached, small, ellipsoid, with a ventral depression, reniform in longitudinal section, the dorsal surfaces pitted, covered with a tanniniferous, non-fibrous sarcotesta; raphe branches obscure; endosperm with numerous, deep, pit-like ruminations; embryos at or near base of seed.
# Calamus disjunctus
# Stems  clustered, climbing, 7.7(3.0–15.0) m long, 1.1(0.6–2.0) cm diameter. Leaf sheaths  tubular, closed opposite the
# petiole, with a knee below the petiole; leaf sheaths with numerous spicules borne on short, low, horizontal ridges, easily detached and leaving the sheaths with ridges only; ocreas short, membranous, not spiny, with external and internal abscission zone, splitting and falling early; flagella absent; petioles 4.0(0.0–10.0) cm long; rachises 41.0(25.5–70.0) cm long, the apices extended into an elongate cirrus, without reduced or vestigial pinnae, adaxially flat, abaxially with more or less regularly arranged (at least proximally), distantly spaced clusters of dark–tipped, recurved spines, terminating in a stub, without a shallow groove adaxially; pinnae  6(4–10) per side of rachis, regularly arranged,
# rhombic, the lateral veins diverging, the two distal margins praemorse, without spinules on veins; proximalmost pinnae sometimes much reduced, sometimes swept back across the sheath; middle pinnae 18.5(10.2–29.7) cm long, 6.7(4.0–12.0) cm wide. Inflorescences  diverging from sheath well below sheath apex, with two vertical ridges distal to point
# of divergence, erect to arching, short, without any recurved spines, terminating in a short, obscure stub; peduncles long, slender, pendulous, not or sparsely spiny, or very short, not spiny, without a prophyll scar at the apex; prophylls flattened, persistent, usually non–spiny, splitting only at the apex by two short, lateral splits; partial inflorescences stalked; rachis bracts much reduced, papery, with one side of the oblique apex extended into a longer limb; rachillae sessile; staminate inflorescences branched to 3 orders, 31.6(26.0–49.0) cm long; staminate rachillae 0.4(0.3–0.5) cm long, with alternately and distichously arranged flowers; flowers not recorded; pistillate inflorescences branched to 2 orders, 25.2(22.0–27.0) cm long; pistillate rachillae 2.9(1.7–5.0) cm long, with alternately and distichously arranged dyads of 1 pistillate and 1 neuter flower borne on short, stout pedicels; pistillate calyces cupular, shallowly 3-lobed; fruits  globose, 16.3(12.3–18.4) mm long, 13.4(9.9–16.7) mm diameter, brownish, pale brown, greenish–brown,
# orangey-brown, or red; fruiting perianths explanate; fruit scales deeply channeled longitudinally; seeds 1 per fruit, basally attached, small, ellipsoid, with a ventral depression, reniform in longitudinal section, the dorsal surfaces pitted, covered with a tanniniferous, non-fibrous sarcotesta; raphe branches obscure; endosperm with pit-like ruminations; embryos at or near base of seed.
# Calamus glaucescens
# Stems  clustered, climbing, 4.0 m long, 1.0(0.9–1.3) cm diameter. Leaf sheaths  tubular, closed opposite the petiole,
# with a knee below the petiole; leaf sheath spines slender, triangular, concave at the base proximally, dense, yellowish-brown to dark brown; ocreas short, membranous, not spiny, with external and internal abscission zone, splitting and falling early; flagella absent; petioles 11.2(8.0–13.0) cm long, petioles and rachises with long, straight, yellowish, usually solitary spines abaxially and laterally; rachises length not recorded, the apices extended into an elongate cirrus, without reduced or vestigial pinnae, adaxially flat, abaxially with more or less regularly arranged (at least proximally), distantly spaced clusters of dark–tipped, recurved spines, terminating in a stub, without a shallow groove adaxially; pinnae  7 per side of rachis, regularly arranged, rhombic, the lateral veins diverging, the two distal margins praemorse,
# without spinules on veins, grayish-white indumentose abaxially; middle pinnae 20.6(19.0–22.0) cm long, 6.0(3.7–8.8) cm wide. Inflorescences  diverging from sheath well below sheath apex, with two vertical ridges distal to point of
# divergence, arching, short, without any recurved spines, terminating in a short, obscure stub; peduncles long, slender, pendulous, sparsely spiny, without a prophyll scar at the apex; prophylls flattened, persistent, non–spiny, splitting only at the apex by two short, lateral splits; partial inflorescences stalked; rachis bracts much reduced, papery, with one side of the oblique apex extended into a longer limb; rachillae sessile; staminate inflorescences branching not recorded, 24.5 cm long; staminate rachillae and flowers not recorded; pistillate inflorescences branched to 2 orders, 24.5 cm long; pistillate rachillae 0.7 cm long, with alternately and distichously arranged dyads of 1 pistillate and 1 neuter flower borne on short, stout pedicels, the neuter flowers borne on well-developed pedicels; pistillate calyces cupular, shallowly 3-lobed; fruits  not recorded.
# Calamus hallierianus
# Stems  clustered, rarely solitary, climbing, 11.8(3.0–20.0) m long, 1.9(0.7–3.2) cm diameter. Leaf sheaths  tubular,
# closed opposite the petiole, with a knee below the petiole; leaf sheaths with numerous spicules borne on short, low, horizontal ridges, easily detached and leaving the sheaths with ridges only, sometimes with larger spines present; ocreas short, membranous, not spiny, with external and internal abscission zone, splitting and falling early; flagella absent; petioles 22.7(1.0–86.0) cm long; rachises 67.8(47.0–141.0) cm long, the apices extended into an elongate cirrus, without reduced or vestigial pinnae, adaxially flat, abaxially with more or less regularly arranged (at least proximally), distantly spaced clusters of dark–tipped, recurved spines, terminating in a stub, without a shallow groove adaxially; pinnae  7(4–10) per side of rachis, regularly arranged, rhombic, the lateral veins diverging, the two distal
# margins praemorse, without spinules on veins, grayish-white indumentose abaxially; middle pinnae 25.5(13.0–45.0) cm long, 9.1(3.0–17.5) cm wide; proximalmost pinnae sometimes much reduced and swept back across the sheath. Inflorescences  diverging from sheath well below sheath apex, with two vertical ridges distal to point of divergence,
# erect to arching, short, without any recurved spines, terminating in a short, obscure stub; peduncles very short, not spiny, without a prophyll scar at the apex; prophylls flattened, persistent, usually non–spiny, splitting only at the apex by two short, lateral splits; partial inflorescences stalked; rachis bracts much reduced, papery, with one side of the oblique apex extended into a longer limb; rachillae sessile; staminate inflorescences branching not recorded, 30.8(27.0–34.5) cm long; staminate rachillae and flowers not recorded; pistillate inflorescences branched to 2 orders, 51.3(25.0–81.0) cm long; pistillate rachillae 3.3(1.8–4.5) cm long, with alternately and distichously arranged dyads of 1 pistillate and 1 neuter flower borne on short, stout pedicels; pistillate calyces cupular, shallowly 3-lobed; fruits
# globose, 15.1(11.3–19.6) cm long, 13.0(9.2–16.5) mm diameter, color not recorded; fruiting perianths explanate; fruit scales deeply channeled longitudinally; seeds 1 per fruit, basally attached, small, ellipsoid, with a ventral depression, reniform in longitudinal section, the dorsal surfaces pitted, covered with a tanniniferous, non-fibrous sarcotesta; raphe branches obscure; endosperm with deep, pit-like ruminations; embryos at or near base of seed.
# Calamus pseudoconcolor
# Stems  clustered, climbing, 2.3(1.0–4.0) m long, 1.0(0.6–1.2) cm diameter. Leaf sheaths  tubular, closed opposite the
# petiole, with a knee below the petiole; leaf sheaths with numerous, scattered spicules, easily detached, sometimes with larger spines present; ocreas short, membranous, not spiny, with external and internal abscission zone, splitting and falling early; flagella absent; petioles 7.3(1.0–14.0) cm long, petioles and rachises sometimes with long, straight, yellowish, usually solitary spines abaxially and laterally; rachises 51.0 cm long, the apices extended into an elongate
# cirrus, without reduced or vestigial pinnae, adaxially flat, abaxially with more or less regularly arranged (at least
# proximally), distantly spaced clusters of dark–tipped, recurved spines, terminating in a stub, without a shallow groove adaxially; pinnae  8(6–10) per side of rachis, regularly arranged, rhombic, the lateral veins diverging, the two distal
# margins praemorse, without spinules on veins, with few to numerous, small, brown scales abaxially; proximalmost
# pinnae sometimes swept back across the sheath; middle pinnae 15.0(11.6–18.0) cm long, 5.8(4.5–8.0) cm wide. Inflorescences  diverging from sheath well below sheath apex, with two vertical ridges distal to point of divergence,
# arching, short, without any recurved spines, terminating in a short, obscure stub; peduncles long, slender, pendulous, not or sparsely spiny, without a prophyll scar at the apex; prophylls flattened, persistent, usually non–spiny, splitting
# only at the apex by two short, lateral splits; partial inflorescences stalked; rachis bracts much reduced, papery, with one side of the oblique apex extended into a longer limb; rachillae sessile; staminate inflorescences not recorded; pistillate inflorescences branched to 2 orders, 29.0 cm long; pistillate rachilla 0.7 cm long, with alternately and distichously
# arranged dyads of 1 pistillate and 1 neuter flower borne on short, stout pedicels; pistillate calyces cupular, shallowly 3-lobed; fruits  ellipsoid, size and color not recorded; fruiting perianths explanate; fruit scales deeply channeled
# longitudinally; seeds 1 per fruit, basally attached, small, ellipsoid, with a ventral depression, reniform in longitudinal
# section, the dorsal surfaces pitted, covered with a tanniniferous, non-fibrous sarcotesta; raphe branches obscure; endosperm homogeneous; embryos at or near base of seed. Distribution and habitat:— Southeastern  Sumatra and western Java (Fig. 107) in lowland rainforest at 300(100–
# 600) m elevation.
# Calamus subangulatus
# Stems  clustered, rarely solitary, climbing, 7.3(1.8–20.0) m long, 0.9(0.5–1.7) cm diameter. Leaf sheaths  tubular,
# closed opposite the petiole, with a knee below the petiole; leaf sheath spines stout, triangular, concave at the base
# proximally, horizontally spreading, scattered, yellowish-brown to dark brown; ocreas short, membranous, not spiny, with external and internal abscission zone, splitting and falling early; flagella absent; petioles 1.1(0.0–4.5) cm long; rachises 42.8(32.0–60.0), the apices extended into an elongate cirrus, without reduced or vestigial pinnae, adaxially flat, abaxially with more or less regularly arranged (at least proximally), distantly spaced clusters of dark–tipped, recurved spines, terminating in a stub, without a shallow groove adaxially; pinnae  12(8–15) per side of rachis,
# regularly arranged and spreading in the same plane, or irregularly arranged, often in groups, sometimes spreading in different planes, or arranged in remote clusters, the pinnae of a cluster spreading in different planes, or arranged in divergent pairs, linear to lanceolate, sometimes divaricate, with or usually without spinules on veins adaxially or abaxially, usually with numerous, small, brown scales abaxially, the lateral veins approximately parallel, one terminating subapically, leaving a distinct or obscure, adaxial ‘broken’ vein; proximalmost pinnae swept back across the sheath, sometimes much reduced; middle pinnae 20.2(10.0–35.5) cm long, 1.5(0.7–2.6) cm wide. Inflorescences
# diverging from sheath well below sheath apex, with two vertical ridges distal to point of divergence, erect to arching, short, without any recurved spines, terminating in a short, obscure stub; peduncles very short, not spiny, without a prophyll scar at the apex; prophylls flattened, persistent, usually non–spiny, splitting only at the apex by two short, lateral splits; partial inflorescences stalked; rachis bracts much reduced, papery, with one side of the oblique apex extended into a longer limb; rachillae sessile; staminate inflorescences branched to 3 orders, 14.0(8.0–22.0) cm long; staminate rachillae 1.0(0.7–1.5) cm long, with alternately and distichously arranged flowers; staminate flowers not recorded; pistillate inflorescences branched to 2 orders, 16.5(10.5–25.0) cm long; pistillate rachillae 3.0(1.2–5.5) cm long, with alternately and distichously arranged dyads of 1 pistillate and 1 neuter flower borne on short, stout pedicels; pistillate calyces cupular, shallowly 3-lobed; fruits  globose, 19.2(15.0–24.1) mm long, 14.4(11.5–18.2) mm diameter,
# brown, brownish, pale brown, light brown, dark brown, reddish-brown, chocolate brown, or orange; fruiting perianths obconic; fruit scales deeply channeled longitudinally; seeds 1 per fruit, basally attached, large, globose, not reniform in longitudinal section, the dorsal surfaces pitted, covered with a tanniniferous, non-fibrous sarcotesta; raphe branches obscure; endosperm with numerous, deep, pit-like ruminations; embryos at or near base of seed.
